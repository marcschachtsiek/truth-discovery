# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

from matplotlib import pyplot as plt

# %%
filename = "run2-200-200-20"
df = pd.read_csv(os.path.join("results", filename + ".csv"))

# %%
filename = "run3-200-200-20"
df = pd.read_csv(os.path.join("results", filename + ".csv"))

best = df[(df['coverage_dist'] == 'F_TruncPareto') & 
          (df['truth_dist'] == 'F_TruncPareto') & 
          (df['distinct_dist'] == 'F_TruncPareto') & 
          (df['spread_dist'] == 'F_TruncPareto')]

best[['Majority_score', 'TruthFinder_score', 'TwoEstimates_score', 'ThreeEstimates_score']]
# Out:
#       Majority_score  TruthFinder_score  TwoEstimates_score  \
# 1600             200                200                   2
#
#       ThreeEstimates_score
# 1600                   200

# %%
df[df['ThreeEstimates_score'] == df['ThreeEstimates_score'].min()]
# Out:
#       n_sources  n_dataitems  n_distinct         coverage_dist  \
# 433         200          200          20      TruncExponential
# 634         200          200          20    F_TruncExponential
# 818         200          200          20    H_TruncExponential
# 825         200          200          20    H_TruncExponential
# 1310        200          200          20    F_TruncExponential
# 1314        200          200          20    F_TruncExponential
# 1364        200          200          20  F_H_TruncExponential
# 1460        200          200          20      TruncExponential
# 1511        200          200          20    H_TruncExponential
# 1553        200          200          20               Uniform
# 1558        200          200          20               Uniform
# 1593        200          200          20         F_TruncPareto
# 1798        200          200          20      TruncExponential
# 1803        200          200          20      TruncExponential
# ...
